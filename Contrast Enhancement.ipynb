# %%
import pandas as pd
import numpy as np
import cv2 as cv
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input,Dense,Flatten,Conv2D,BatchNormalization,MaxPooling2D,Dropout, Add
from tensorflow.keras.models import Model

# useful for getting number of output classes
from glob import glob

import matplotlib.pyplot as plt
from matplotlib import image
from PIL import Image

# %%
Path = "archive/colored_images/Mild/"

# %%
def noisy(noise_typ,image):
    if noise_typ == "gauss":
        row,col,ch= image.shape
        mean = 0
        var = 0.0001
        sigma = var**0.05
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy =  gauss + image
        return noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 1.0
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(image.size * s_vs_p)
        coords = [np.random.randint(0, i, int(num_salt))
              for i in image.shape]
        out[coords] = 1

        # Pepper mode
        num_pepper = np.ceil(image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i , int(num_pepper))
              for i in image.shape]
        out[coords] = 1
        return out
    elif noise_typ == "poisson":
        vals = len(np.unique(image))
        vals = 2 ** np.ceil(np.log2(vals))
        noisy = np.random.poisson(image * vals) / float(vals)
        return noisy
    elif noise_typ =="speckle":
        row,col,ch = image.shape
        gauss = np.random.randn(row,col,ch)
        gauss = gauss.reshape(row,col,ch)        
        noisy = image + image * gauss
        return noisy

# %%
img = cv.imread(Path+"0a61bddab956.png")  
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
l = img.max()
plt.imshow(img)
l
# Out:
# 255

# %%
Noise = noisy("s&p",img)
plt.imshow(Noise)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV) #convert it to hsv
hsv[...,2] = hsv[...,2]*0.2
img1 = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
Noise2 = noisy("s&p",img1)

plt.imshow(Noise2)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
def PreProcessData(ImagePath):
    X_=[]
    y_=[]
    count=0
    for imageDir in os.listdir(ImagePath):
        if count<2131:
            try:
                count=count+1
                img = cv.imread(ImagePath + imageDir)
                img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
                img_y = cv.resize(img,(224,224))
                hsv = cv.cvtColor(img_y, cv.COLOR_BGR2HSV) #convert it to hsv
                hsv[...,2] = hsv[...,2]*0.2
                img_1 = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
                Noisey_img = noisy("s&p",img_1)
                X_.append(Noisey_img)
                y_.append(img_y)
            except:
                pass
    X_ = np.array(X_)
    y_ = np.array(y_)
    
    return X_,y_

# %%
X_,y_ = PreProcessData(Path)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
X_.size
# Out:
# 55695360

# %% [markdown]
# # Model

# %%
from keras.layers import add, Conv2D,MaxPooling2D,UpSampling2D,Input,BatchNormalization, RepeatVector, Reshape
from keras.layers.merge import concatenate
from keras.models import Model

# %%
def InstantiateModel(in_):
    
    model_1 = Conv2D(16,(3,3), activation='relu',padding='same',strides=1)(in_)
    model_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_1)
    model_1 = Conv2D(64,(2,2), activation='relu',padding='same',strides=1)(model_1)
    
    model_2 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(in_)
    model_2 = Conv2D(64,(2,2), activation='relu',padding='same',strides=1)(model_2)
    
    model_2_0 = Conv2D(64,(2,2), activation='relu',padding='same',strides=1)(model_2)
    
    model_add = add([model_1,model_2,model_2_0])
    
    model_3 = Conv2D(64,(3,3), activation='relu',padding='same',strides=1)(model_add)
    model_3 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_3)
    model_3 = Conv2D(16,(2,2), activation='relu',padding='same',strides=1)(model_3)
    
    model_3_1 = Conv2D(32,(3,3), activation='relu',padding='same',strides=1)(model_add)
    model_3_1 = Conv2D(16,(2,2), activation='relu',padding='same',strides=1)(model_3_1)
    
    model_3_2 = Conv2D(16,(2,2), activation='relu',padding='same',strides=1)(model_add)
    
    model_add_2 = add([model_3_1,model_3_2,model_3])
    
    model_4 = Conv2D(16,(3,3), activation='relu',padding='same',strides=1)(model_add_2)
    model_4_1 = Conv2D(16,(3,3), activation='relu',padding='same',strides=1)(model_add)
    #Extension
    model_add_3 = add([model_4_1,model_add_2,model_4])
    
    model_5 = Conv2D(16,(3,3), activation='relu',padding='same',strides=1)(model_add_3)
    model_5 = Conv2D(16,(2,2), activation='relu',padding='same',strides=1)(model_add_3)
    
    model_5 = Conv2D(3,(3,3), activation='relu',padding='same',strides=1)(model_5)
    
    return model_5

# %%
Input_Sample = Input(shape=(224,224,3))
Output_ = InstantiateModel(Input_Sample)
Model_Enhancer = Model(inputs=Input_Sample, outputs=Output_)

# %%
Model_Enhancer.compile(optimizer="adam", loss='mean_squared_error')
Model_Enhancer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 4640        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 64) 8256        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 64) 8256        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 64) 16448       conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 64) 0           conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 224, 224, 64) 36928       add[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 224, 224, 32) 18464       add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 32) 18464       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 224, 224, 16) 2064        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 224, 224, 16) 4112        add[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 224, 224, 16) 2064        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 224, 224, 16) 0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 224, 224, 16) 9232        add[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 224, 224, 16) 2320        add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 224, 224, 16) 0           conv2d_13[0][0]
#                                                                  add_1[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 224, 224, 16) 1040        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 224, 224, 3)  435         conv2d_15[0][0]
# ==================================================================================================
# Total params: 134,067
# Trainable params: 134,067
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(Model_Enhancer,to_file='model_.png',show_shapes=True, show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model_.png')

# %%
def GenerateInputs(X,y):
    for i in range(len(X)):
        X_input = X[i].reshape(1,224,224,3)
        y_input = y[i].reshape(1,224,224,3)
        yield (X_input,y_input)
Model_Enhancer.fit_generator(GenerateInputs(X_,y_),epochs=50,verbose=1,steps_per_epoch=5,shuffle=True)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 5/5 [==============================] - 18s 48ms/step - loss: 5983.8701
# Epoch 2/50
# 5/5 [==============================] - 0s 37ms/step - loss: 1599.9177
# Epoch 3/50
# 5/5 [==============================] - 0s 37ms/step - loss: 438.7883
# Epoch 4/50
# 5/5 [==============================] - 0s 37ms/step - loss: 358.1236
# Epoch 5/50
# 5/5 [==============================] - 0s 36ms/step - loss: 403.8674
# Epoch 6/50
# 5/5 [==============================] - 0s 37ms/step - loss: 245.2653
# Epoch 7/50
# 5/5 [==============================] - 0s 37ms/step - loss: 384.7268
# Epoch 8/50
# 5/5 [==============================] - 0s 37ms/step - loss: 289.2411: 0s - loss: 289.241
# Epoch 9/50
# 5/5 [==============================] - 0s 40ms/step - loss: 442.8712
# Epoch 10/50
# 5/5 [==============================] - 0s 38ms/step - loss: 318.4574
# Epoch 11/50
# 5/5 [==============================] - 0s 38ms/step - loss: 260.5982
# Epoch 12/50
# 5/5 [==============================] - 0s 39ms/step - loss: 252.0101
# Epoch 13/50
# 5/5 [==============================] - 0s 40ms/step - loss: 239.7067
# Epoch 14/50
# 5/5 [==============================] - 0s 43ms/step - loss: 172.4539: 0s - loss: 177.85
# Epoch 15/50
# 5/5 [==============================] - 0s 39ms/step - loss: 202.4901
# Epoch 16/50
# 5/5 [==============================] - 0s 48ms/step - loss: 409.6190
# Epoch 17/50
# 5/5 [==============================] - 0s 48ms/step - loss: 252.0827
# Epoch 18/50
# 5/5 [==============================] - 0s 49ms/step - loss: 226.3784
# Epoch 19/50
# 5/5 [==============================] - 0s 48ms/step - loss: 140.6114
# Epoch 20/50
# 5/5 [==============================] - 0s 42ms/step - loss: 212.8100
# Epoch 21/50
# 5/5 [==============================] - 0s 41ms/step - loss: 135.6508
# Epoch 22/50
# 5/5 [==============================] - 0s 39ms/step - loss: 259.2796
# Epoch 23/50
# 5/5 [==============================] - 0s 45ms/step - loss: 314.0984
# Epoch 24/50
# 5/5 [==============================] - 0s 38ms/step - loss: 234.8016
# Epoch 25/50
# 5/5 [==============================] - 0s 38ms/step - loss: 220.0533
# Epoch 26/50
# 5/5 [==============================] - 0s 42ms/step - loss: 177.3971
# Epoch 27/50
# 5/5 [==============================] - 0s 39ms/step - loss: 178.6693
# Epoch 28/50
# 5/5 [==============================] - 0s 44ms/step - loss: 155.6741
# Epoch 29/50
# 5/5 [==============================] - 0s 40ms/step - loss: 246.9712
# Epoch 30/50
# 5/5 [==============================] - 0s 39ms/step - loss: 136.7295
# Epoch 31/50
# 5/5 [==============================] - 0s 41ms/step - loss: 131.6021
# Epoch 32/50
# 5/5 [==============================] - 0s 41ms/step - loss: 152.6133
# Epoch 33/50
# 5/5 [==============================] - 0s 37ms/step - loss: 198.4765
# Epoch 34/50
# 5/5 [==============================] - 0s 37ms/step - loss: 164.7859
# Epoch 35/50
# 5/5 [==============================] - 0s 40ms/step - loss: 86.7435
# Epoch 36/50
# 5/5 [==============================] - 0s 39ms/step - loss: 299.6546
# Epoch 37/50
# 5/5 [==============================] - 0s 38ms/step - loss: 328.0166
# Epoch 38/50
# 5/5 [==============================] - 0s 39ms/step - loss: 219.5898
# Epoch 39/50
# 5/5 [==============================] - 0s 40ms/step - loss: 223.8727
# Epoch 40/50
# 5/5 [==============================] - 0s 41ms/step - loss: 189.3264
# Epoch 41/50
# 5/5 [==============================] - 0s 39ms/step - loss: 234.6392
# Epoch 42/50
# 5/5 [==============================] - 0s 39ms/step - loss: 229.4351
# Epoch 43/50
# 5/5 [==============================] - 0s 38ms/step - loss: 311.9711
# Epoch 44/50
# 5/5 [==============================] - 0s 39ms/step - loss: 240.4621
# Epoch 45/50
# 5/5 [==============================] - 0s 41ms/step - loss: 208.6829
# Epoch 46/50
# 5/5 [==============================] - 0s 39ms/step - loss: 173.2839
# Epoch 47/50
# 5/5 [==============================] - 0s 37ms/step - loss: 124.4499
# Epoch 48/50
# 5/5 [==============================] - 0s 37ms/step - loss: 155.1756
# Epoch 49/50
# 5/5 [==============================] - 0s 38ms/step - loss: 171.8836
# Epoch 50/50
# 5/5 [==============================] - 0s 37ms/step - loss: 149.3963

# %%
TestPath="archive/colored_images/Moderate/"

# %%
def ExtractTestInput(ImagePath):
    img = cv.imread(ImagePath)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img_ = cv.resize(img,(224,224))
    hsv = cv.cvtColor(img_, cv.COLOR_BGR2HSV) #convert it to hsv
    hsv[...,2] = hsv[...,2]*0.2
    img1 = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
    Noise = noisy("s&p",img1)
    Noise = Noise.reshape(1,224,224,3)
    return Noise

# %%
ImagePath=TestPath+"000c1434d8d7.png"
image_for_test = ExtractTestInput(ImagePath)
Prediction = Model_Enhancer.predict(image_for_test)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
Prediction = Prediction.reshape(224,224,3)
plt.imshow(Prediction)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
Image_test=TestPath+"000c1434d8d7.png"
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
img_1 = cv.imread(Image_test)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (224, 224))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(5,5,1+1)
img_ = ExtractTestInput(Image_test)
img_ = img_.reshape(224,224,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(5,5,1+2)
img_[:,:,:] = Prediction[:,:,:]
plt.title("Enhanced Image",fontsize=20)
plt.imshow(img_)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
ImagePath=TestPath+"00e4ddff966a.png"
image_for_test = ExtractTestInput(ImagePath)
Prediction = Model_Enhancer.predict(image_for_test)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
Image_test=TestPath+"00e4ddff966a.png"
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
img_1 = cv.imread(Image_test)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (224, 224))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(5,5,1+1)
img_ = ExtractTestInput(Image_test)
img_ = img_.reshape(224,224,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(5,5,1+2)
img_[:,:,:] = Prediction[:,:,:]
plt.title("Enhanced Image",fontsize=20)
plt.imshow(img_)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
ImagePath=TestPath+"1b8ad0afe9fb.png"
image_for_test = ExtractTestInput(ImagePath)
Prediction = Model_Enhancer.predict(image_for_test)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
Image_test=TestPath+"1b8ad0afe9fb.png"
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
img_1 = cv.imread(Image_test)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (224, 224))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(5,5,1+1)
img_ = ExtractTestInput(Image_test)
img_ = img_.reshape(224,224,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(5,5,1+2)
img_[:,:,:] = Prediction[:,:,:]
plt.title("Enhanced Image",fontsize=20)
plt.imshow(img_)
# Out:
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# C:\Users\Vishal\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
