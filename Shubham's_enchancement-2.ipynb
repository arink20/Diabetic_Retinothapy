# %%
import cv2
import numpy as np
import pywt
from skimage.util import img_as_ubyte
import os

# Apply CLAHE
def apply_CLAHE(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    clahe_image = clahe.apply(image)
    return clahe_image

# Perform reflection padding
def reflect_padding(image):
    reflected_image = cv2.copyMakeBorder(image, top=1, bottom=1, left=1, right=1, 
                                         borderType=cv2.BORDER_REFLECT)
    _, thresholded_image = cv2.threshold(reflected_image, 20, 255, cv2.THRESH_BINARY)
    return thresholded_image, reflected_image

# High-frequency enhancement
def high_freq_enhancement(image):
    low_freq_image = cv2.GaussianBlur(image, (0, 0), 3)
    high_freq_image = cv2.addWeighted(image, 1.5, low_freq_image, -0.5, 0)  # subtract low-freq component
    return high_freq_image

# Image Processing
def image_processing(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_COLOR)
    img = img[:,:,1]  # Extract the green channel

    mask, img = reflect_padding(img)  # Apply reflect padding
    img = cv2.bitwise_and(img, img, mask=mask)  # Apply mask
    img = high_freq_enhancement(img)  # High-frequency enhancement

    coeffs = pywt.dwt2(img, 'haar')
    LL, (LH, HL, HH) = coeffs

    img_clahe = apply_CLAHE(img)

    coeffs_clahe = pywt.dwt2(img_clahe, 'haar')
    LL_prime, _ = coeffs_clahe

    U, S, VT = np.linalg.svd(LL, full_matrices=True)
    U_prime, S_prime, VT_prime = np.linalg.svd(LL_prime, full_matrices=True)

    mean_S = np.mean(S)
    mean_S_prime = np.mean(S_prime)
    S_double_prime = mean_S_prime / mean_S

    n = 1
    S_transformed = np.power(S, n)
    S_star = np.zeros_like(LL)
    np.fill_diagonal(S_star, S_double_prime * S_transformed)

    LL_double_prime = U @ S_star @ VT

    coeffs_inv = LL_double_prime, (LH, HL, HH)
    img_final = pywt.idwt2(coeffs_inv, 'haar')

    return img_final

def apply_image_processing(image_directory, output_directory):
    # Create the output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)

    # Iterate over each file in the input image directory
    for filename in os.listdir(image_directory):
        # Check if the file is an image
        if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
            # Read the image file
            image_path = os.path.join(image_directory, filename)
            output_path = os.path.join(output_directory, filename)

            # Apply image processing
            processed_image = image_processing(image_path)

            # Save the processed image
            cv2.imwrite(output_path, processed_image)

            print(f"Processed: {filename}")

    print("Image processing applied to all images.")

# Example usage
input_directory = "New/Disease_Grading/Training_Set"
output_directory = "New/Disease_Grading_method_2/Training_Set"
apply_image_processing(input_directory, output_directory)
# Out:
# Processed: IDRiD_001.jpg
# Processed: IDRiD_002.jpg
# Processed: IDRiD_003.jpg
# Processed: IDRiD_004.jpg
# Processed: IDRiD_005.jpg
# Processed: IDRiD_006.jpg
# Processed: IDRiD_007.jpg
# Processed: IDRiD_008.jpg
# Processed: IDRiD_009.jpg
# Processed: IDRiD_010.jpg
# Processed: IDRiD_011.jpg
# Processed: IDRiD_012.jpg
# Processed: IDRiD_013.jpg
# Processed: IDRiD_014.jpg
# Processed: IDRiD_015.jpg
# Processed: IDRiD_016.jpg
# Processed: IDRiD_017.jpg
# Processed: IDRiD_018.jpg
# Processed: IDRiD_019.jpg
# Processed: IDRiD_020.jpg
# Processed: IDRiD_021.jpg
# Processed: IDRiD_022.jpg
# Processed: IDRiD_023.jpg
# Processed: IDRiD_024.jpg
# Processed: IDRiD_025.jpg
# Processed: IDRiD_026.jpg
# Processed: IDRiD_027.jpg
# Processed: IDRiD_125.jpg
# Processed: IDRiD_126.jpg
# Processed: IDRiD_127.jpg
# Processed: IDRiD_128.jpg
# Processed: IDRiD_129.jpg
# Processed: IDRiD_130.jpg
# Processed: IDRiD_131.jpg
# Processed: IDRiD_132.jpg
# Processed: IDRiD_133.jpg
# Processed: IDRiD_134.jpg
# Processed: IDRiD_135.jpg
# Processed: IDRiD_136.jpg
# Processed: IDRiD_137.jpg
# Processed: IDRiD_138.jpg
# Processed: IDRiD_139.jpg
# Processed: IDRiD_140.jpg
# Processed: IDRiD_141.jpg
# Processed: IDRiD_142.jpg
# Processed: IDRiD_143.jpg
# Processed: IDRiD_144.jpg
# Processed: IDRiD_145.jpg
# Processed: IDRiD_146.jpg
# Processed: IDRiD_147.jpg
# Processed: IDRiD_148.jpg
# Processed: IDRiD_149.jpg
# Processed: IDRiD_150.jpg
# Processed: IDRiD_151.jpg
# Processed: IDRiD_152.jpg
# Processed: IDRiD_153.jpg
# Processed: IDRiD_154.jpg
# Processed: IDRiD_155.jpg
# Processed: IDRiD_156.jpg
# Processed: IDRiD_157.jpg
# Processed: IDRiD_158.jpg
# Processed: IDRiD_159.jpg
# Processed: IDRiD_160.jpg
# Processed: IDRiD_161.jpg
# Processed: IDRiD_162.jpg
# Processed: IDRiD_163.jpg
# Processed: IDRiD_164.jpg
# Processed: IDRiD_165.jpg
# Processed: IDRiD_166.jpg
# Processed: IDRiD_167.jpg
# Processed: IDRiD_168.jpg
# Processed: IDRiD_169.jpg
# Processed: IDRiD_170.jpg
# Processed: IDRiD_171.jpg
# Processed: IDRiD_172.jpg
# Processed: IDRiD_173.jpg
# Processed: IDRiD_174.jpg
# Processed: IDRiD_175.jpg
# Processed: IDRiD_176.jpg
# Processed: IDRiD_177.jpg
# Processed: IDRiD_178.jpg
# Processed: IDRiD_179.jpg
# Processed: IDRiD_180.jpg
# Processed: IDRiD_181.jpg
# Processed: IDRiD_182.jpg
# Processed: IDRiD_183.jpg
# Processed: IDRiD_184.jpg
# Processed: IDRiD_185.jpg
# Processed: IDRiD_186.jpg
# Processed: IDRiD_187.jpg
# Processed: IDRiD_188.jpg
# Processed: IDRiD_189.jpg
# Processed: IDRiD_190.jpg
# Processed: IDRiD_191.jpg
# Processed: IDRiD_192.jpg
# Processed: IDRiD_193.jpg
# Processed: IDRiD_194.jpg
# Processed: IDRiD_195.jpg
# Processed: IDRiD_196.jpg
# Processed: IDRiD_197.jpg
# Processed: IDRiD_198.jpg
# Processed: IDRiD_199.jpg
# Processed: IDRiD_200.jpg
# Processed: IDRiD_201.jpg
# Processed: IDRiD_202.jpg
# Processed: IDRiD_203.jpg
# Processed: IDRiD_204.jpg
# Processed: IDRiD_205.jpg
# Processed: IDRiD_206.jpg
# Processed: IDRiD_207.jpg
# Processed: IDRiD_208.jpg
# Processed: IDRiD_209.jpg
# Processed: IDRiD_210.jpg
# Processed: IDRiD_211.jpg
# Processed: IDRiD_212.jpg
# Processed: IDRiD_213.jpg
# Processed: IDRiD_214.jpg
# Processed: IDRiD_215.jpg
# Processed: IDRiD_216.jpg
# Processed: IDRiD_217.jpg
# Processed: IDRiD_218.jpg
# Processed: IDRiD_219.jpg
# Processed: IDRiD_220.jpg
# Processed: IDRiD_221.jpg
# Processed: IDRiD_222.jpg
# Processed: IDRiD_223.jpg
# Processed: IDRiD_224.jpg
# Processed: IDRiD_225.jpg
# Processed: IDRiD_226.jpg
# Processed: IDRiD_227.jpg
# Processed: IDRiD_228.jpg
# Processed: IDRiD_229.jpg
# Processed: IDRiD_230.jpg
# Processed: IDRiD_231.jpg
# Processed: IDRiD_232.jpg
# Processed: IDRiD_233.jpg
# Processed: IDRiD_234.jpg
# Processed: IDRiD_235.jpg
# Processed: IDRiD_236.jpg
# Processed: IDRiD_237.jpg
# Processed: IDRiD_238.jpg
# Processed: IDRiD_239.jpg
# Processed: IDRiD_240.jpg
# Processed: IDRiD_241.jpg
# Processed: IDRiD_242.jpg
# Processed: IDRiD_243.jpg
# Processed: IDRiD_244.jpg
# Processed: IDRiD_245.jpg
# Processed: IDRiD_246.jpg
# Processed: IDRiD_247.jpg
# Processed: IDRiD_248.jpg
# Processed: IDRiD_249.jpg
# Processed: IDRiD_250.jpg
# Processed: IDRiD_251.jpg
# Processed: IDRiD_252.jpg
# Processed: IDRiD_253.jpg
# Processed: IDRiD_254.jpg
# Processed: IDRiD_255.jpg
# Processed: IDRiD_256.jpg
# Processed: IDRiD_257.jpg
# Processed: IDRiD_258.jpg
# Processed: IDRiD_259.jpg
# Processed: IDRiD_260.jpg
# Processed: IDRiD_261.jpg
# Processed: IDRiD_262.jpg
# Processed: IDRiD_263.jpg
# Processed: IDRiD_264.jpg
# Processed: IDRiD_265.jpg
# Processed: IDRiD_266.jpg
# Processed: IDRiD_267.jpg
# Processed: IDRiD_268.jpg
# Processed: IDRiD_269.jpg
# Processed: IDRiD_270.jpg
# Processed: IDRiD_271.jpg
# Processed: IDRiD_272.jpg
# Processed: IDRiD_273.jpg
# Processed: IDRiD_274.jpg
# Processed: IDRiD_275.jpg
# Processed: IDRiD_276.jpg
# Processed: IDRiD_277.jpg
# Processed: IDRiD_278.jpg
# Processed: IDRiD_279.jpg
# Processed: IDRiD_280.jpg
# Processed: IDRiD_281.jpg
# Processed: IDRiD_282.jpg
# Processed: IDRiD_283.jpg
# Processed: IDRiD_284.jpg
# Processed: IDRiD_285.jpg
# Processed: IDRiD_286.jpg
# Processed: IDRiD_287.jpg
# Processed: IDRiD_288.jpg
# Processed: IDRiD_289.jpg
# Processed: IDRiD_290.jpg
# Processed: IDRiD_291.jpg
# Processed: IDRiD_292.jpg
# Processed: IDRiD_293.jpg
# Processed: IDRiD_294.jpg
# Processed: IDRiD_295.jpg
# Processed: IDRiD_296.jpg
# Processed: IDRiD_297.jpg
# Processed: IDRiD_298.jpg
# Processed: IDRiD_299.jpg
# Processed: IDRiD_300.jpg
# Processed: IDRiD_301.jpg
# Processed: IDRiD_302.jpg
# Processed: IDRiD_303.jpg
# Processed: IDRiD_304.jpg
# Processed: IDRiD_305.jpg
# Processed: IDRiD_306.jpg
# Processed: IDRiD_307.jpg
# Processed: IDRiD_308.jpg
# Processed: IDRiD_309.jpg
# Processed: IDRiD_310.jpg
# Processed: IDRiD_311.jpg
# Processed: IDRiD_312.jpg
# Processed: IDRiD_313.jpg
# Processed: IDRiD_314.jpg
# Processed: IDRiD_315.jpg
# Processed: IDRiD_316.jpg
# Processed: IDRiD_317.jpg
# Processed: IDRiD_318.jpg
# Processed: IDRiD_319.jpg
# Processed: IDRiD_320.jpg
# Processed: IDRiD_321.jpg
# Processed: IDRiD_322.jpg
# Processed: IDRiD_323.jpg
# Processed: IDRiD_324.jpg
# Processed: IDRiD_325.jpg
# Processed: IDRiD_326.jpg
# Processed: IDRiD_327.jpg
# Processed: IDRiD_328.jpg
# Processed: IDRiD_329.jpg
# Processed: IDRiD_330.jpg
# Processed: IDRiD_331.jpg
# Processed: IDRiD_332.jpg
# Processed: IDRiD_333.jpg
# Processed: IDRiD_334.jpg
# Processed: IDRiD_335.jpg
# Processed: IDRiD_336.jpg
# Processed: IDRiD_337.jpg
# Processed: IDRiD_338.jpg
# Processed: IDRiD_339.jpg
# Processed: IDRiD_340.jpg
# Processed: IDRiD_341.jpg
# Processed: IDRiD_342.jpg
# Processed: IDRiD_343.jpg
# Processed: IDRiD_344.jpg
# Processed: IDRiD_345.jpg
# Processed: IDRiD_346.jpg
# Processed: IDRiD_347.jpg
# Processed: IDRiD_348.jpg
# Processed: IDRiD_349.jpg
# Processed: IDRiD_350.jpg
# Processed: IDRiD_351.jpg
# Processed: IDRiD_352.jpg
# Processed: IDRiD_353.jpg
# Processed: IDRiD_354.jpg
# Processed: IDRiD_355.jpg
# Processed: IDRiD_356.jpg
# Processed: IDRiD_357.jpg
# Processed: IDRiD_358.jpg
# Processed: IDRiD_359.jpg
# Processed: IDRiD_360.jpg
# Processed: IDRiD_361.jpg
# Processed: IDRiD_362.jpg
# Processed: IDRiD_363.jpg
# Processed: IDRiD_364.jpg
# Processed: IDRiD_365.jpg
# Processed: IDRiD_366.jpg
# Processed: IDRiD_367.jpg
# Processed: IDRiD_368.jpg
# Processed: IDRiD_369.jpg
# Processed: IDRiD_370.jpg
# Processed: IDRiD_371.jpg
# Processed: IDRiD_372.jpg
# Processed: IDRiD_373.jpg
# Processed: IDRiD_374.jpg
# Processed: IDRiD_375.jpg
# Processed: IDRiD_376.jpg
# Processed: IDRiD_377.jpg
# Processed: IDRiD_378.jpg
# Processed: IDRiD_379.jpg
# Processed: IDRiD_380.jpg
# Processed: IDRiD_381.jpg
# Processed: IDRiD_382.jpg
# Processed: IDRiD_383.jpg
# Processed: IDRiD_384.jpg
# Processed: IDRiD_385.jpg
# Processed: IDRiD_386.jpg
# Processed: IDRiD_387.jpg
# Processed: IDRiD_388.jpg
# Processed: IDRiD_389.jpg
# Processed: IDRiD_390.jpg
# Processed: IDRiD_391.jpg
# Processed: IDRiD_392.jpg
# Processed: IDRiD_393.jpg
# Processed: IDRiD_394.jpg
# Processed: IDRiD_395.jpg
# Processed: IDRiD_396.jpg
# Processed: IDRiD_397.jpg
# Processed: IDRiD_398.jpg
# Processed: IDRiD_399.jpg
# Processed: IDRiD_400.jpg
# Processed: IDRiD_401.jpg
# Processed: IDRiD_402.jpg
# Processed: IDRiD_403.jpg
# Processed: IDRiD_404.jpg
# Processed: IDRiD_405.jpg
# Processed: IDRiD_406.jpg
# Processed: IDRiD_407.jpg
# Processed: IDRiD_408.jpg
# Processed: IDRiD_409.jpg
# Processed: IDRiD_410.jpg
# Processed: IDRiD_411.jpg
# Processed: IDRiD_412.jpg
# Processed: IDRiD_413.jpg
# Image processing applied to all images.
